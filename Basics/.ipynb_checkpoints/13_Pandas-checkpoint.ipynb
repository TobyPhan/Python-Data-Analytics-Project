# %%
import pandas as pd
df = pd.read_csv('filePath')

# %%
df['total_bedrooms']
df.total_bedrooms

# %%
df.total_bedrooms[0]
df['total_bedrooms'][21]

# %%
# !pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/555.1 kB ? eta -:--:--
#    ---------------------------------------- 555.1/555.1 kB 2.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/774.9 kB ? eta -:--:--
#    ---------------------------------------- 774.9/774.9 kB 7.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 26.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ------- -------------------------------- 5.2/27.9 MB 25.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 8.1/27.9 MB 18.6 MB/s eta 0:00:02
#    ------------------ --------------------- 12.6/27.9 MB 19.7 MB/s eta 0:00:01
#    --------------------- ------------------ 15.2/27.9 MB 17.8 MB/s eta 0:00:01
#    ------------------------ --------------- 17.0/27.9 MB 15.7 MB/s eta 0:00:01
# ...

# %%
from datasets import load_dataset
dataset = load_dataset('filepath from website')

# %%
df = dataset['train'].to_pandas()   #imported as a dataframe
df

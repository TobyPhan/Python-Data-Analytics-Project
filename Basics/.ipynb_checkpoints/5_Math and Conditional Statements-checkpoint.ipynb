# %%
2 +3
# Out:
# 5

# %%
3-1
# Out:
# 2

# %%
four = 4
four.__sub__(2)
# Out:
# 2

# %%
4 - 2
# Out:
# 2

# %%
5//2  #gets float

# %%
5 % 2 #remainder of division

# %%
min_salary = 20_000 #_ is ignored by the interpreter
max_salary = 80_000

# %%
avg_salary = (min_salary + max_salary) / 2

# %%
applicant_1 = "Kelly"
applicant_2 = "Luke"

# %%
applicant_1, applicant_2 = applicant_2,applicant_1

# %%
x=1
x = x +1
x

# %%
x *= 2

# %%
salary_kelly = 60_000
salary_luke = 40_000

# %%
salary_kelly == salary_luke   #True or False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 salary_kelly == salary_luke   #True or False
#
# NameError: name 'salary_kelly' is not defined

# %%
1 ==1
# Out:
# True

# %%
if True:                  #If Conditions
    print("Whats up")
# Out:
# Whats up

# %%
applicant_skill = "SQL"
job_skill = "SQL"
years_experience = 6

if job_skill == applicant_skill:
    print("Skills Match")
# Out:
# Skills Match

# %%
applicant_skill = "SQL"
job_skill = "Python"
years_experience = 6

if job_skill == applicant_skill:
    print("Skills Match")
elif years_experience >=5:
    print("Enough Experience; No SQL")
elif applicant_skill == "Python":
    print("This applicant should know SQL")
else:
    print("No skill or experience")
# Out:
# Enough Experience; No SQL

# %%
if job_skill == applicant_skill:
    pass    #being able to pass through the code

# %%
data_science_jobs = [
    {
        'job_title': 'Data Scientist',
        'job_skills': "['Python', 'SQL', 'Machine Learning']",
        'job_date': '2023-05-12'
    },
    {
        'job_title': 'Data Engineer',
        'job_skills': "['AWS', 'Python', 'TensorFlow']",
        'job_date': '2023-05-18'
    },
    {
        'job_title': 'Data Analyst',
        'job_skills': "['Python', 'Data Analysis', 'SQL']",
        'job_date': '2023-05-06'
    },
    {
        'job_title': 'Machine Learning Engineer',
        'job_skills': "['Python', 'PyTorch', 'Deep Learning']",
        'job_date': '2023-05-20'
    },
    {
        'job_title': 'Business Intelligence Analyst',
        'job_skills': "['Power BI', 'SQL', 'Excel']",
        'job_date': '2023-05-22'
    },
    {
        'job_title': 'Data Architect',
        'job_skills': "['Azure', 'SQL', 'Data Modeling']",
        'job_date': '2023-05-25'
    },
    {
        'job_title': 'Analytics Engineer',
        'job_skills': "['dbt', 'SQL', 'Python']",
        'job_date': '2023-05-27'
    },
    {
        'job_title': 'AI Engineer',
        'job_skills': "['Python', 'LLMs', 'LangChain']",
        'job_date': '2023-05-29'
    },
    {
        'job_title': 'Data Engineer',
        'job_skills': "['Spark', 'Python', 'Kafka']",
        'job_date': '2023-06-01'
    },
    {
        'job_title': 'Research Scientist',
        'job_skills': "['Python', 'Statistics', 'Machine Learning']",
        'job_date': '2023-06-03'
    },
    {
        'job_title': 'Data Analyst',
        'job_skills': "['Tableau', 'SQL', 'Excel']",
        'job_date': '2023-06-05'
    },
    {
        'job_title': 'Data Scientist',
        'job_skills': "['R', 'Python', 'Predictive Modeling']",
        'job_date': '2023-06-08'
    },
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 7, 27, 13, 49, 57, 512919)

# %%
data_science_jobs[0]['job_date']                       #convert to the correct object
# Out:
# '2023-05-12'

# %%
type(data_science_jobs[0]['job_date'])  #lets convert this from string to time
# Out:
# str

# %%
test_date = data_science_jobs[0]['job_date']

print(datetime.strptime(test_date,'%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
for job in data_science_jobs:   #How to clean up the date times
    job['job_date']= datetime.strptime(job['job_date'],'%Y-%m-%d')      #Loops every lines and convert oneby one into a correct format and save to previous location
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['AWS', 'Python', 'TensorFlow']",
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['Python', 'Data Analysis', 'SQL']",
#   'job_date': datetime.datetime(2023, 5, 6, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python', 'PyTorch', 'Deep Learning']",
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': "['Power BI', 'SQL', 'Excel']",
#   'job_date': datetime.datetime(2023, 5, 22, 0, 0)},
#  {'job_title': 'Data Architect',
#   'job_skills': "['Azure', 'SQL', 'Data Modeling']",
#   'job_date': datetime.datetime(2023, 5, 25, 0, 0)},
#  {'job_title': 'Analytics Engineer',
#   'job_skills': "['dbt', 'SQL', 'Python']",
# ...

# %%
import ast

for job in data_science_jobs:   
    job['job_date']= datetime.strptime(job['job_date'],'%Y-%m-%d')                     #date is already converted 
    job['job_skills'] = ast.literal_eval(job['job_skills'])
data_science_jobs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import ast
#       2
#       3 for job in data_science_jobs:
# ----> 4     job['job_date']= datetime.strptime(job['job_date'],'%Y-%m-%d')                     #date is already converted
#       5     job['job_skills'] = ast.literal_eval(job['job_skills'])
#       6 data_science_jobs
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

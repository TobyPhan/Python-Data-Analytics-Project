# %%
job_work_from_home = True
job_health_insurance = True                                # AND operator

job_work_from_home and job_health_insurance
# Out:
# True

# %%
job_work_from_home = True
job_health_insurance = False                            

job_work_from_home and job_health_insurance
# Out:
# False

# %%
job_work_from_home = True
job_health_insurance = False                               # OR operator                   

job_work_from_home or job_health_insurance
# Out:
# True

# %%
job_work_from_home = True
job_health_insurance = False                               # NOT operator                   

job_work_from_home or not job_health_insurance
# Out:
# True

# %%
"Data" in "Data Analyst"                                 # Membership Arguments. If item is within another item

# %%
job_skills = ['python','r','sql']

'python' in job_skills
# Out:
# True

# %%
salary_kelly = 100_000                                     # Identiy Operators: If one correlates to another
salary_luke = 100_000

salary_kelly is salary_luke                   # IS operator is verifying the memory location of the value they are holding
# Out:
# False

# %%
print(id(salary_kelly))
print(id(salary_luke))
# Out:
# 2159630570448
# 2159630570480

# %%
core_skills = ['Python','R','SQL']
lukes_skills = core_skills

lukes_skills is core_skills
# Out:
# True

# %%
bin(42)                                                  # Bitwise Operators
# Out:
# '0b101010'

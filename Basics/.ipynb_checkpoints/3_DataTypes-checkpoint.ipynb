# %%
total_salary = 110000
bonus_salary = 10000

# %%
type(total_salary)
# Out:
# int

# %%
base_salary = total_salary - bonus_salary
base_salary
# Out:
# 100000

# %%
job_title = "Data Analyst"
type(job_title)
# Out:
# str

# %%
'Data' + 'Nerd'
# Out:
# 'DataNerd'

# %%
'Data Nerd'.capitalize()
# Out:
# 'Data nerd'

# %%
job_id = 102
type(job_id)
# Out:
# int

# %%
job_id = float(102)
type(job_id)
# Out:
# float

# %%
"This is a string"
# Out:
# 'This is a string'

# %%
skill = "Python"
type(skill)
# Out:
# str

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.lower()
# Out:
# 'python'

# %%
skill = "Python"
skill.lower()
# Out:
# 'python'

# %%
skill.replace("P","J")
# Out:
# 'Jython'

# %%
job_title = "Data Analyst" # renaming Data as Doto
job_title.replace("a","o",2)
# Out:
# 'Doto Analyst'

# %%
# split argument
job_title.split(sep=" ", maxsplit=1)
# Out:
# ['Data', 'Analyst']

# %%
str.__add__("Data", "Analyst+")  #merging
# Out:
# 'DataAnalyst+'

# %%
"Data".__add__(" Analyst")
# Out:
# 'Data Analyst'

# %%
"Data" + " Analyst" #simpler than dunder method
# Out:
# 'Data Analyst'

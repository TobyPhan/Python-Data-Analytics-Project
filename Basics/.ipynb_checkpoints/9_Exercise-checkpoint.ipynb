# %%
for job in job_roles:
   qualified = True

for job in job_roles:
    for skill in my_skills:
        if skill not in job['skills']:
            qualified = False
            print(skill)
            print(job['skills'])
        break

# %%
qualified_roles = []          #Determine which jobs you're qualified for

for job in job_roles:
    for skill in my_skills:
        if skill not in job['skills']:
            qualified = False
            break
        if qualified:
            qualified_roles.append(job['role'])

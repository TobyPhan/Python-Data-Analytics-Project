# %%
skills_list = ['Python','SQL','Excel']
len(skills_list)
# Out:
# 3

# %%
count = 0
for skill in skills_list:
    count +=1
count
# Out:
# 3

# %%
print(skills_list)
type(skills_list)
range(0,2)
# Out:
# ['Python', 'SQL', 'Excel']
# range(0, 2)

# %%
data_salaries = [95000,100000,85000,97000,140000]
min(data_salaries)
# Out:
# 85000

# %%
def calculate_salary(base_salary, bonus_rate):                        #Building our own functions
    total_salary = base_salary * (1+bonus_rate)
    return total_salary

# %%
calculate_salary(150000,.2)
# Out:
# 180000.0

# %%
def calculate_salary(base_salary, bonus_rate = .1):                        
    total_salary = base_salary * (1+bonus_rate)
    return total_salary

# %%
calculate_salary(150000)
# Out:
# 165000.0

# %%
mul_two = lambda x: x*2                                            # lAMBDA
mul_two(3)
# Out:
# 6

# %%
(lambda x: x*2)(3)
# Out:
# 6

# %%
(lambda x,y: x*2 + 2)(3,2)
# Out:
# 8

# %%
salary_list = [100000,200000,150000,120000,80000,750000]

def calculate_salary(base_salary, bonus_rate = .1):                        
    total_salary = base_salary * (1+bonus_rate)
    return total_salary

total_salary_list = [calculate_salary(salary) for salary in salary_list]

total_salary_list
# Out:
# [110000.00000000001,
#  220000.00000000003,
#  165000.0,
#  132000.0,
#  88000.0,
#  825000.0000000001]

# %%
total_salary_list = [(lambda x: x)(salary) for salary in salary_list]
total_salary_list
# Out:
# [100000, 200000, 150000, 120000, 80000, 750000]

# %%
total_salary_list = [(lambda x: x*1.1)(salary) for salary in salary_list]
total_salary_list
# Out:
# [110000.00000000001,
#  220000.00000000003,
#  165000.0,
#  132000.0,
#  88000.0,
#  825000.0000000001]

# %%
filter(lambda job: job['remote'], jobs_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 filter(lambda job: job['remote'], jobs_data)
#
# NameError: name 'jobs_data' is not defined

# %%
list(filter(lambda job: job['remote'] and "Python" in job['job_skills'], jobs_data))           #filter where remote is true and python is a skill
